# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import seaborn as sns
import pandas as pd

from DRflow.dr.plot import *
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
name = 'coil-100'
names = ['caltech', 'cinic10', 'coil-100', 'fashionmnist', 'flowers', 'MNIST','oxford_buildings','paintings','paris_buildings','dogs','pets']
sizes = [28,50,200,300]
size = 200
c = 10
cs = [2,4,6,8,10]

# %%
name = 'paintings'
size=100
input_folder = 'data/{}/dr_data/'.format(name)
output_folder = 'data/{}/dr_figures/'.format(name)
thumbnail_folder = 'data/{}/thumbnails/size{}/'.format(name, size)

# %%
name = 'paintings'
size=100


for name in names:
    for size in sizes:
        input_folder = '../../data/{}/dr_data/size{}/'.format(name,size)
        output_folder = '../../data/{}/dr_figures/all/'.format(name,size)
        thumbnail_folder = '../../data/{}/thumbnails/size{}/'.format(name,size)
        
        for file in os.listdir(input_folder):
            plot_projection(input_folder + file, 
                output_folder, thumbnail_folder,  loc=[0,1], fs= (100, 100))
# Out:
# ../../data/caltech/dr_data/size50/caltech_size50_c8_ISM_n7.csv
# -------- ../../data/caltech/dr_figures/all/caltech_size50_c8_ISM_n7.png
# ../../data/caltech/dr_data/size50/caltech_size50_c2_GRP.csv
# -------- ../../data/caltech/dr_figures/all/caltech_size50_c2_GRP.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x123982950> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x123982950> returned a result with an error set
#
# ...

# %%
plot_projection('../../data/paintings/dr_data/size100/paintings_UMAP_n5_d0.1.csv', 
                output_folder, thumbnail_folder,  loc=[0,1], fs= (100, 100))
# Out:
# ../../data/paintings/dr_data/size100/paintings_UMAP_n5_d0.1.csv
# -------- ../../data/paintings/dr_figures/size100/paintings_UMAP_n5_d0.1.png
